# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=sns.load_dataset('mpg')
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.lineplot(x="displacement",y="weight",data=df)
plt.show()

# %%
sns.lineplot(x="displacement",y="weight",data=df,hue="acceleration")
plt.show()

# %%
sns.lineplot(x="displacement",y="weight",data=df,hue="acceleration",style="acceleration")
plt.show()

# %%
import pandas as pd
sns.set(style="whitegrid")
df=sns.load_dataset('mpg')
sns.barplot(x="displacement",y="weight",data=df)
plt.show()

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
sns.set(style="whitegrid")
df=sns.load_dataset('mpg')
sns.barplot(x="weight",y="acceleration",data=df)
plt.show()

# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\kush\seaborn-data\mpg.csv')
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.barplot(x="weight",y="model_year",data=df)
plt.show()

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
sns.set(style="whitegrid")
df=sns.load_dataset('mpg')
sns.barplot(x="weight",y="model_year",data=df,hue="displacement")
plt.show()

# %%
sns.barplot(x="weight",y="model_year",data=df,palette="Blues_d")
plt.show()

# %%
sns.barplot(x="weight",y="model_year",data=df,palette="rocket")
plt.show()

# %%
sns.barplot(x="weight",y="model_year",data=df,palette="vlag")
plt.show()

# %%
sns.barplot(x="weight",y="acceleration",data=df,color="orange")
plt.show()

# %%
df=sns.load_dataset('flights')
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
sns.set(style="whitegrid")
df=sns.load_dataset('flights')
sns.barplot(x="year",y="passengers",data=df,hue="year")
plt.show()

# %%
sns.barplot(x="year",y="passengers",data=df,palette="Blues_d")
plt.show()

# %%
sns.barplot(x="year",y="passengers",data=df,palette="vlag")
plt.show()

# %%
sns.barplot(x="year",y="passengers",data=df,palette="rocket")
plt.show()

# %%
sns.barplot(x="year",y="passengers",data=df,color="orange")
plt.show()

# %%
sns.barplot(x="year",y="passengers",data=df,color="red")
plt.show()

# %%
sns.barplot(x="year",y="passengers",data=df,color="purple")
plt.show()

# %%
sns.scatterplot(x="year",y="passengers",data=df)
plt.show()

# %%
sns.scatterplot(x="passengers",y="year",data=df,hue="year",style="year")
plt.show()

# %%
sns.scatterplot(x="passengers",y="year",data=df,hue="year")
plt.show()

# %%
sns.distplot(df['year'])
plt.show()
# Out:
# C:\Users\kush\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['passengers'])
plt.show()
# Out:
# C:\Users\kush\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['year'],hist=False)
plt.show()
# Out:
# C:\Users\kush\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['year'],color="red")
plt.show()
# Out:
# C:\Users\kush\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['year'],color="pink")
plt.show()
# Out:
# C:\Users\kush\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['year'],color="blue")
plt.show()
# Out:
# C:\Users\kush\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['year'],color="green",bins=10,kde=False)
plt.show()
# Out:
# C:\Users\kush\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['year'],color="orange",vertical=True)
plt.show()
# Out:
# C:\Users\kush\anaconda3\lib\site-packages\seaborn\distributions.py:1689: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)

# %%
sns.jointplot(x="passengers",y="year",data=df)
plt.show()

# %%
sns.jointplot(x="passengers",y="year",data=df,color="olive")
plt.show()

# %%
sns.jointplot(x="passengers",y="year",data=df,color="olive",kind="reg")
plt.show()

# %%
sns.boxplot(x="year",y="passengers",data=df)
plt.show()

# %%
sns.boxplot(x="year",y="passengers",data=df,palette="Set1")
plt.show()

# %%
sns.boxplot(x="year",y="passengers",data=df,linewidth=3)
plt.show()

# %%
sns.boxplot(x="year",y="passengers",data=df,order=["Two year","Month-to-month","One year"])
plt.show()

# %%
sns.stripplot(x="year",y="passengers",data=df,hue="year")
plt.show()

# %%
sns.stripplot(x="year",y="passengers",data=df,hue="year",palette="YlGnBu")
plt.show()

# %%
sns.stripplot(x="year",y="passengers",data=df,hue="year",palette="YlGnBu",dodge=True)
plt.show()

# %%
sns.jointplot(x="year",y="passengers",data=df,kind="kde",shade=True)
plt.show()

# %%
sns.jointplot(x="year",y="passengers",data=df,kind="kde",shade=True,cmap="YlGnBu")
plt.show()

# %%
sns.jointplot(x="year",y="passengers",data=df,kind="hex",cmap="YlGnBu")
plt.show()

# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\kush\seaborn-data\mpg.csv')
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.pairplot(df.select_dtypes(['number']), hue="pclass")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pclass'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %%
sns.heatmap(df.corr(),annot=True,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True,cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True,cmap="icefire")
# Out:
# <AxesSubplot:>

# %%
sns.clustermap(df.drop("horsepower",axis=1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15756/797295837.py in <module>
# ----> 1 sns.clustermap(df.drop("horsepower",axis=1))
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\matrix.py in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1404                           colors_ratio=colors_ratio, cbar_pos=cbar_pos)
#    1405
# -> 1406     return plotter.plot(metric=metric, method=method,
# ...

# %%
sns.lineplot(x="displacement",y="weight",data=df,hue="acceleration",ci=False,markers=True)
plt.show()

# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\kush\seaborn-data\mpg.csv')
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.barplot(x="weight",y="model_year",data=df,orient="h")
plt.show()

# %%
sns.barplot(x="weight",y="model_year",data=df,orient="h",color="green")
plt.show()

# %%
sns.barplot(x="weight",y="model_year",data=df,ci=None,hue="weight",orient="h",color="red")
plt.show()
